# %% [markdown]
# # Week 5
# Last week's version included a simple battery class, market class, and a basic Q-learning implementation.
# In this week's version I will:
# - Extend the battery class with an `idle`-action and battery **efficiency**.
# - Extend the market class with **more prices** and **real price data**.
# - Use **linear programming** the see if last week's solution of the agent on the sine wave pricing was actually correct.
# - Plot some curves to **visualize how the agent learns**.

# %% [markdown]
# # 1. Idle action + learning curve

# %% [markdown]
# ## 1.1 Market class

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

class Market:
    def __init__(self, duration_hours=24, timestep_minutes=15, pattern="square", high_price=10, low_price=-10, price_levels_num=10):
        if not (low_price < high_price):
            raise ValueError("Lowest price must be lower than highest price.")
        self.duration_hours = duration_hours
        self.timestep_minutes = timestep_minutes
        self.pattern = pattern
        self.high_price = high_price
        self.low_price = low_price
        self.num_steps = int(duration_hours * 60 / timestep_minutes)
        self.price_levels_num = price_levels_num
        self.prices, self.prices_discrete = self._generate_prices()

    def reset(self):
        self.prices, self.prices_discrete = self._generate_prices()
    
    def _generate_prices(self):
        if self.pattern == "square":
            prices = self._generate_square_wave()
        elif self.pattern == "sinus":
            prices = self._generate_sinus_wave()
        else:
            raise ValueError(f"Unknown pattern type: {self.pattern}")
    
        # Discretize prices
        levels = np.linspace(self.low_price, self.high_price, self.price_levels_num)
        prices_discrete = np.round(
            np.array([levels[np.argmin(np.abs(levels - p))] for p in prices]), 2
        )
    
        return prices, prices_discrete
    
    def _generate_square_wave(self):
        prices = []
        toggle = random.choice([self.high_price, self.low_price])
        i = 0
        while i < self.num_steps:
            block_length = random.randint(2, 16) # how many timesteps this block lasts
            for _ in range(block_length):
                if i >= self.num_steps:
                    break
                prices.append(toggle)
                i += 1
            toggle = self.high_price if toggle == self.low_price else self.low_price
        return np.array(prices)
    
    def _generate_sinus_wave(self):
        x = np.linspace(0, 2 * np.pi * 4, self.num_steps, endpoint=False)
        mid = (self.high_price + self.low_price) / 2
        amplitude = (self.high_price - self.low_price) / 2
        prices = mid + amplitude * np.sin(x)
        return prices
    
    def plot(self):
        x = range(len(self.prices))
        plt.step(x, self.prices, label="Real Prices")
        plt.step(x, self.prices_discrete, label="Discrete Prices", alpha=0.6)
        plt.title("Imbalance Market Prices")
        plt.xlabel(f"Timestep ({self.timestep_minutes} min each)")
        plt.ylabel("Price")
        plt.grid(True, linestyle="--", alpha=0.5)
        plt.legend()
        plt.show()

# %% [markdown]
# ## 1.2 Battery class (extended with an idle action)

# %%
class Battery:    
    def __init__(self, soc=15, capacity=30, power=5):
        if not (0 <= soc <= capacity):
            raise ValueError("SOC must be between 0 and capacity.")
        self.soc = soc # kWh
        self.capacity = capacity # kWh
        self.power = power # kW
        self.history = [] # list of (soc, time, action)

    def get_soc(self):
        return self.soc
    
    def charge(self, duration=15):
        """Charge the battery (duration in minutes)."""
        self.history.append((self.soc, duration, 2))
        energy_added = self.power * (duration / 60)
        soc_before = self.soc
        self.soc = min(self.capacity, self.soc + energy_added)
        return self.soc - soc_before
    
    def idle(self, duration=15):
        """Idle the battery (duration in minutes)."""
        self.history.append((self.soc, duration, 1))
        return 0.0
    
    def discharge(self, duration=15):
        """Discharge the battery (duration in minutes)."""
        self.history.append((self.soc, duration, 0))
        energy_removed = self.power * (duration / 60)
        soc_before = self.soc
        self.soc = max(0, self.soc - energy_removed)
        return self.soc - soc_before
    
    def get_history(self):
        return self.history

    def reset(self, soc=15):
        if not (0 <= soc <= self.capacity):
            raise ValueError("SOC must be between 0 and capacity.")
        self.history = []
        self.soc = soc

    def __repr__(self):
        return f"Battery(SOC={self.soc:.2f}/{self.capacity} kWh)"

# %% [markdown]
# ## 1.3 Q-learning setup

# %% [markdown]
# ### Environment parameters + Q-learning hyperparameters

# %%
import dataclasses
from dataclasses import dataclass

@dataclass
class Config:
    timestep_min = 15
    duration_hours=24
    initial_soc = 15
    capacity = 30
    power = 5
    price_levels_num = 10
    high_price = 10
    low_price = -10
    pattern = "sinus"
    
    # Q-learning
    alpha = 0.05
    gamma = 0.95
    epsilon = 0.2
    n_episodes = 1000

cfg = Config()

# %% [markdown]
# ### Battery and market

# %%
battery = Battery(soc=cfg.initial_soc, capacity=cfg.capacity, power=cfg.power)
market = Market(
    pattern=cfg.pattern, 
    duration_hours=cfg.duration_hours, 
    timestep_minutes=cfg.timestep_min, 
    high_price=cfg.high_price, 
    low_price=cfg.low_price,
    price_levels_num=cfg.price_levels_num,
)
print(battery)
market.plot()
# Out:
# Battery(SOC=15.00/30 kWh)

# %% [markdown]
# ### Q-learning setup

# %%
from enum import IntEnum

class Action(IntEnum):
    IDLE = 0
    CHARGE = 1
    DISCHARGE = 2
    
n_states = (cfg.capacity + 1) + (cfg.capacity + 1) * cfg.price_levels_num
Q = np.zeros((n_states, len(Action)))

possible_prices = np.unique(market.prices_discrete)
price_to_index = { price:index for index,price in enumerate(possible_prices) }

def state_to_index(soc, price):
    soc_bin = int(round(soc))
    price_index = price_to_index[price]
    return soc_bin + (cfg.capacity + 1) * price_index

# %%
def step(time_index, action):
    price = market.prices_discrete[time_index]
    reward = 0.0
    if action == Action.DISCHARGE:
        delivered = -battery.discharge(duration=cfg.timestep_min)
        reward = price * delivered
    elif action == Action.IDLE:
        battery.idle(duration=cfg.timestep_min)
        reward = 0.0
    else:
        stored = battery.charge(duration=cfg.timestep_min)
        reward = -price * stored
    next_index = time_index + 1
    return reward, next_index

# %% [markdown]
# ### Q-Learning

# %%
episode_rewards = []

for _ in range(cfg.n_episodes):
    battery.reset(soc=cfg.initial_soc)
    market.reset()
    t = 0
    s = state_to_index(battery.get_soc(), market.prices_discrete[t])
    total_reward = 0
    while t < market.num_steps:
        if random.random() < cfg.epsilon:
            a = random.choice(list(Action))
        else:
            a = Action(int(np.argmax(Q[s])))

        r, t_next = step(t, a)
        total_reward += r

        if t_next < market.num_steps:
            s_next = state_to_index(battery.get_soc(), market.prices_discrete[t_next])
            td_target = r + cfg.gamma * np.max(Q[s_next])
        else:
            s_next = None
            td_target = r
        
        Q[s, a] += cfg.alpha * (td_target - Q[s, a])
        s = s_next if s_next is not None else s
        t = t_next
    episode_rewards.append(total_reward)

# %%
print("Q-table shape:", Q.shape)
# Out:
# Q-table shape: (341, 3)

# %%
window = 100

plt.plot(np.convolve(episode_rewards, np.ones(window)/window, mode='valid'))
plt.xlabel("Episode")
plt.ylabel(f"Total Reward ({window}-episode MA)")
plt.title("Q-learning Learning Curve")
plt.show()

# %% [markdown]
# ## 1.4 Test the agent

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_actions(battery, market, timestep, initial_soc):
    history = battery.get_history()
    soc_history = []
    time_steps = []
    actions = []
    dt = timestep
    current_time = 0
    current_soc = initial_soc
    for entry in history:
        soc_before, duration_min, action = entry
        steps = int(duration_min / dt) if duration_min >= dt else 1
        for s in range(steps):
            time_steps.append(current_time)
            soc_history.append(current_soc)
            actions.append(action)
            if action == 2:
                # charge
                added = battery.power * (dt / 60)
                current_soc = min(battery.capacity, current_soc + added)
            elif action == 0:
                # discharge
                removed = battery.power * (dt / 60)
                current_soc = max(0, current_soc - removed)
            # if action == 1 (idle): do nothing
            current_time += 1

    # Convert market prices to align with time_steps
    price_ts = market.prices[:len(time_steps)] if len(market.prices) >= len(time_steps) else np.pad(
        market.prices,
        (0, len(time_steps) - len(market.prices)),
        constant_values=(market.prices[-1] if len(market.prices) > 0 else 0)
    )

    # Plot
    fig, ax1 = plt.subplots(figsize=(14,4))
    ax2 = ax1.twinx()

    # Price as stepped line
    ax1.step(range(len(price_ts)), price_ts, where='post', color='tab:blue', linewidth=2, label='Market price [€/kWh]')
    ax1.set_ylabel('Price [€/kWh]', color='tab:blue')
    ax1.tick_params(axis='y', labelcolor='tab:blue')

    # SOC as line
    ax2.plot(range(len(soc_history)), soc_history, color='tab:orange', label='Battery SOC (kWh)')
    ax2.set_ylabel('SOC (kWh)', color='tab:orange')
    ax2.tick_params(axis='y', labelcolor='tab:orange')

    # Mark actions
    for idx, act in enumerate(actions):
        if act is None:
            continue
        if act == 2:
            ax2.scatter(idx, soc_history[idx], color='green', marker='^', s=40, label='Charge' if idx==0 else "")
        elif act == 0:
            ax2.scatter(idx, soc_history[idx], color='red', marker='v', s=40, label='Discharge' if idx==0 else "")
        elif act == 1:
            ax2.scatter(idx, soc_history[idx], color='gray', marker='o', s=30, label='Idle' if idx==0 else "")

    ax1.set_title('Market prices and Battery actions over time')
    ax1.set_xlabel('Timestep')
    ax1.grid(True, linestyle='--', alpha=0.4)
    fig.tight_layout()
    plt.show()

# %%
battery.reset(soc=cfg.initial_soc)
market.reset()
total_profit = 0.0
for t in range(market.num_steps):
    s = state_to_index(battery.get_soc(), market.prices_discrete[t])
    a = Action(int(np.argmax(Q[s])))
    r, _ = step(t, a)
    total_profit += r
print(f"One-day simulation profit: €{total_profit:.2f}")

# Plot results
plot_actions(battery=battery, market=market, timestep=cfg.timestep_min, initial_soc=cfg.initial_soc)
# Out:
# One-day simulation profit: €744.55

# %% [markdown]
# # 2. Optimization

# %%
import pulp

# --------------------------
# 1) Build & solve the MILP
# --------------------------
def solve_optimal_battery_schedule(prices,
                                   capacity_kwh,
                                   power_kw,
                                   initial_soc_kwh,
                                   timestep_min=15,
                                   enforce_terminal_soc=True):
    """
    prices: array-like of €/kWh (length T)
    capacity_kwh, power_kw, initial_soc_kwh as in your Battery
    timestep_min: minutes per step
    enforce_terminal_soc: if True, force s_T == initial_soc (fair comparison)
    Returns dict with optimal c[], d[], s[], profit
    """
    prices = np.asarray(prices)
    T = len(prices)
    dt_h = timestep_min / 60.0
    e_step_max = power_kw * dt_h  # kWh per step

    # Problem (maximize revenue). Pulp maximizes if we use LpMaximize.
    prob = pulp.LpProblem("Battery_Arbitrage", pulp.LpMaximize)

    # Decision variables
    c = [pulp.LpVariable(f"c_{t}", lowBound=0, upBound=e_step_max) for t in range(T)]  # charge kWh at step t
    d = [pulp.LpVariable(f"d_{t}", lowBound=0, upBound=e_step_max) for t in range(T)]  # discharge kWh at step t
    # SOC at every step t (state AFTER step t is s_{t+1}); here we'll store s_0..s_T
    s = [pulp.LpVariable(f"s_{t}", lowBound=0, upBound=capacity_kwh) for t in range(T + 1)]

    # Binary selectors to prevent simultaneous charge/discharge
    y_c = [pulp.LpVariable(f"yc_{t}", cat="Binary") for t in range(T)]
    y_d = [pulp.LpVariable(f"yd_{t}", cat="Binary") for t in range(T)]

    # Initial SOC
    prob += (s[0] == initial_soc_kwh)

    # Dynamics & logic constraints
    for t in range(T):
        # SOC transition: s_{t+1} = s_t + c_t - d_t
        prob += (s[t + 1] == s[t] + c[t] - d[t])

        # At most one of charge/discharge active (allows idle when both 0)
        prob += (y_c[t] + y_d[t] <= 1)

        # Link charge/discharge to binaries (big-M with M = e_step_max)
        prob += (c[t] <= e_step_max * y_c[t])
        prob += (d[t] <= e_step_max * y_d[t])

    # (Optional) Terminal SOC constraint for fair comparison across strategies
    if enforce_terminal_soc:
        prob += (s[T] == initial_soc_kwh)

    # Objective: maximize ∑ (price * discharge  −  price * charge)
    profit_expr = pulp.lpSum(prices[t] * (d[t] - c[t]) for t in range(T))
    prob += profit_expr

    # Solve
    _ = prob.solve(pulp.PULP_CBC_CMD(msg=False))

    # Extract solution
    c_opt = np.array([pulp.value(var) for var in c])
    d_opt = np.array([pulp.value(var) for var in d])
    s_opt = np.array([pulp.value(var) for var in s])
    profit = float(sum(prices * (d_opt - c_opt)))

    return {
        "charge": c_opt,
        "discharge": d_opt,
        "soc": s_opt,                 # length T+1 (includes s_0 and s_T)
        "profit": profit,
        "step_energy_max": e_step_max
    }

# Solve LP on the current market day (using the same discretized prices the RL uses)
lp_result = solve_optimal_battery_schedule(
    prices=market.prices_discrete,            # align with RL state/step
    capacity_kwh=cfg.capacity,
    power_kw=cfg.power,
    initial_soc_kwh=cfg.initial_soc,
    timestep_min=cfg.timestep_min,
    enforce_terminal_soc=True
)

# ----------------------------------------
# 2) Compute RL profit again (same market)
# ----------------------------------------
# We'll run a greedy pass using the learned Q (already trained in your previous cell)
battery.reset(soc=cfg.initial_soc)
market.reset()  # re-generate prices for an apples-to-apples fresh day if you want; 
                # comment this out if you want to compare on *exactly* the last plotted RL day.

rl_total_profit = 0.0
rl_actions = []  # store the chosen action per step (0,1,2)
rl_soc = [battery.get_soc()]  # SOC trace (start)
for t in range(market.num_steps):
    s_idx = int(round(battery.get_soc())) + (cfg.capacity + 1) * \
            (np.where(np.unique(market.prices_discrete) == market.prices_discrete[t])[0][0])
    a = Action(int(np.argmax(Q[s_idx])))
    rl_actions.append(int(a))
    r, _ = step(t, a)
    rl_total_profit += r
    rl_soc.append(battery.get_soc())

print(f"[RL] One-day simulation profit: €{rl_total_profit:.2f}")
print(f"[LP] One-day optimal profit   : €{lp_result['profit']:.2f}")

# ---------------------------------------------------------
# 3) Plot the LP schedule with the same style as your plot
# ---------------------------------------------------------
def plot_actions_from_schedule(prices, soc, charge, discharge, timestep_min, capacity, power, title_suffix="(LP Optimal)"):
    """
    Draw a plot like your `plot_actions`, but from arrays (charge/discharge/soc).
    - prices: array length T (continuous prices)
    - soc: array length T+1 (s_0..s_T)
    - charge, discharge: arrays length T (kWh at each step)
    """
    T = len(prices)
    # Rebuild action markers compatible with your style: 2=charge, 0=discharge, 1=idle
    eps = 1e-6
    actions = []
    soc_history = []
    time_steps = list(range(T))
    for t in range(T):
        soc_history.append(soc[t])
        if charge[t] > eps and discharge[t] <= eps:
            actions.append(2)
        elif discharge[t] > eps and charge[t] <= eps:
            actions.append(0)
        else:
            actions.append(1)

    # Plot: prices (left axis, stepped), SOC (right axis, line), action markers
    fig, ax1 = plt.subplots(figsize=(14, 4))
    ax2 = ax1.twinx()

    ax1.step(range(T), prices[:T], where='post', linewidth=2, label='Market price [€/kWh]')
    ax1.set_ylabel('Price [€/kWh]')
    ax1.tick_params(axis='y')

    ax2.plot(range(T), soc_history, linewidth=2, label='Battery SOC (kWh)')
    ax2.set_ylabel('SOC (kWh)')
    ax2.tick_params(axis='y')

    # Mark actions
    for idx, act in enumerate(actions):
        if act == 2:
            ax2.scatter(idx, soc_history[idx], marker='^', s=40, label='Charge' if idx == 0 else "")
        elif act == 0:
            ax2.scatter(idx, soc_history[idx], marker='v', s=40, label='Discharge' if idx == 0 else "")
        elif act == 1:
            ax2.scatter(idx, soc_history[idx], marker='o', s=30, label='Idle' if idx == 0 else "")

    ax1.set_title(f'Market prices and Battery actions over time {title_suffix}')
    ax1.set_xlabel(f'Timestep ({timestep_min} min each)')
    ax1.grid(True, linestyle='--', alpha=0.4)
    fig.tight_layout()
    plt.show()

# Plot RL result (your original helper) and LP optimal result, back-to-back
# First, RL (same as you already did):
plot_actions(battery=battery, market=market, timestep=cfg.timestep_min, initial_soc=cfg.initial_soc)

# Then, LP optimal (on the same market.prices for this run)
plot_actions_from_schedule(
    prices=market.prices,
    soc=lp_result["soc"],
    charge=lp_result["charge"],
    discharge=lp_result["discharge"],
    timestep_min=cfg.timestep_min,
    capacity=cfg.capacity,
    power=cfg.power,
    title_suffix="(LP Optimal)"
)
# Out:
# [RL] One-day simulation profit: €744.55
# [LP] One-day optimal profit   : €800.10
